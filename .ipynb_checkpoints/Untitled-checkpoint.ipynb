# %%
import pandas as pd
ruta = "data/2022_PlebiscitoConstitucional_DatosPlebiscito.xlsx"
df = pd.read_excel(ruta, skiprows = 5)
df.head()
# Out:
#    Unnamed: 0   Unnamed: 1                    Unnamed: 2  Unnamed: 3  \
# 0  Nro Región       Región    Circunscripción senatorial    Distrito
# 1           1  DE TARAPACA  CIRCUNSCRIPCION SENATORIAL 2  DISTRITO 2
# 2           1  DE TARAPACA  CIRCUNSCRIPCION SENATORIAL 2  DISTRITO 2
# 3           1  DE TARAPACA  CIRCUNSCRIPCION SENATORIAL 2  DISTRITO 2
# 4           1  DE TARAPACA  CIRCUNSCRIPCION SENATORIAL 2  DISTRITO 2
#
#       Unnamed: 4                 Unnamed: 5  \
# 0         Comuna  Circunscripción electoral
# 1  ALTO HOSPICIO              ALTO HOSPICIO
# 2  ALTO HOSPICIO              ALTO HOSPICIO
# 3  ALTO HOSPICIO              ALTO HOSPICIO
# 4  ALTO HOSPICIO              ALTO HOSPICIO
#
#                                 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                                    Local       Mesa   Nro.Voto
# 1  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA         78          1
# 2  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA         78          2
# ...
